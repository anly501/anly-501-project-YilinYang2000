# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Part 1 Twitter API in python

# %% [markdown]
# As I mentioned in data gathering page, I would like to detect the frequency of words to gain a plot. More than this, I plan to use Sentiment analysis to give each tweet a positive or negative attitude.
# At this time, I will use countVectorizer to generate a bag of words and count frequency for the tweets I gained. Then I will use nltk package to calculate the sentiment scores for each tweets.

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from sklearn import svm
import nltk
import warnings
warnings.filterwarnings('ignore')
pytt = pd.read_csv("/Users/yangyilin/Desktop/anly-501-project-YilinYang2000-1/data/00-raw-data/twitterpython.csv")

# %% [markdown]
# ##### Find the dataset has the NA value or not
# There is no NA values in this dataset.

# %%
pytt.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      Unnamed: 0     id   lang  author_id  created_at   text
# 0         False  False  False      False       False  False
# 1         False  False  False      False       False  False
# 2         False  False  False      False       False  False
# 3         False  False  False      False       False  False
# 4         False  False  False      False       False  False
# ..          ...    ...    ...        ...         ...    ...
# 589       False  False  False      False       False  False
# 590       False  False  False      False       False  False
# 591       False  False  False      False       False  False
# 592       False  False  False      False       False  False
# 593       False  False  False      False       False  False
#
# [594 rows x 6 columns]>

# %% [markdown]
# ##### Use spacy pipeline as I learned in anly580 to do text normalization and text preprocessing

# %% [markdown]
# Since there are a lot of useless puntuations, urls, commas, numbers, highercase, etc will affect our results of frequencies, I decided to remove them all by using pipeline in spacy.

# %%
import re
import spacy
from spacy.language import Language


pipeline = spacy.load('en_core_web_sm')

# http://emailregex.com/
email_re = r"""(?:[a-z0-9!#$%&'*+/=?^_`{|}~-]+(?:\.[a-z0-9!#$%&'*+/=?^_`{|}~-]+)*|"(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21\x23-\x5b\x5d-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])*")@(?:(?:[a-z0-9](?:[a-z0-9-]*[a-z0-9])?\.)+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?|\[(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?|[a-z0-9-]*[a-z0-9]:(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21-\x5a\x53-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])+)\])"""

# replace = [ (pattern-to-replace, replacement),  ...]
replace = [
    (r"<a[^>]*>(.*?)</a>", r"\1"),  # Matches most URLs
    (email_re, "email"),            # Matches emails
    (r"(?<=\d),(?=\d)", ""),        # Remove commas in numbers
    (r"\d+", "number"),              # Map digits to special token <numbr>
    (r"[\t\n\r\*\.\@\,\-\/]", " "), # Punctuation and other junk
    (r"\s+", " ")                   # Stips extra whitespace
]

twitter_sentences = []
for i, d in enumerate(pytt['text']):
    for repl in replace:
        d = re.sub(repl[0], repl[1], d)
    twitter_sentences.append(d)


@Language.component("pyttPreprocessor")
def ng20_preprocess(doc):
    tokens = [token for token in doc 
              if not any((token.is_stop, token.is_punct))]
    tokens = [token.lemma_.lower().strip() for token in tokens]
    tokens = [token for token in tokens if token]
    return " ".join(tokens)


pipeline.add_pipe("pyttPreprocessor")
# Out:
# 2022-10-07 16:23:40.284262: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <function __main__.ng20_preprocess(doc)>

# %% [markdown]
# ##### Pass data through spacy pipeline

# %%
docs = []
for sent in twitter_sentences:
    docs.append(pipeline(sent))

# %% [markdown]
# ##### Generate bag of words and count the frequecies of words

# %% [markdown]
# I want to learn about through these keywords, what kind of problems platform users discuss more in their daily lives, so I used the bag of words I generated to count the frequencies of each word appears by using CountVectorizer and set a dataframe which contains texts and counts. Then I sort the table with descending order to see the result more clearly.

# %%
countvectorizer = CountVectorizer()
ttbow = countvectorizer.fit(docs)
features = ttbow.vocabulary_.keys()
counts = ttbow.vocabulary_.values()
ttbow=pd.DataFrame({'words':features,'counts':counts})

# %%
ttbow = ttbow.sort_values(by=['counts'],ascending=False)

# %%
ttbow
# Out:
#                     words  counts
# 674  zznumbernnumbervdscj     733
# 173       zfpgcrvwjnumber     732
# 650  zfdnumberwgqcxnumber     731
# 48                 zecops     730
# 414                  york     729
# ..                    ...     ...
# 11                   acti       4
# 36                    act       3
# 633           acquisition       2
# 316              accurate       1
# 276                accept       0
#
# [734 rows x 2 columns]

# %% [markdown]
# During this dataframe,
#
#
# words: name of the count words
#
#
# counts: frequencies that each word appears

# %% [markdown]
# ##### Export dataframe to csv file for further use

# %%
ttbow.to_csv("/Users/yangyilin/Desktop/anly-501-project-YilinYang2000-1/data/00-raw-data/wordfreqpython.csv")

# %% [markdown]
# #### Then I want to do sentiment analysis for using this dataframe
# Sentiment analysis for this part of data cleaning is very important. The sentimentintensityanalyzer can automatically helps me to calculate the score of a text is positive, neutral, negative or compound. I used for loop to calculate text by text and then I get a whole dictionary. Then I trasnferred dictionary to dataframe and split sentiment scores into three columns for the future visualization. Finally, I combine text and sentiment scores together to see the result clearly.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
def getSentiments(df):
    sid = SentimentIntensityAnalyzer()
    tweet_str = ""
    tweetscore = []
    for tweet in df['text']:
        tweet_str = tweet_str + " " + tweet
        score = sid.polarity_scores(tweet_str)
        tweetscore.append(score)
    return tweetscore

# %% [markdown]
# ##### Create a dataframe for sentiment analysis as tweets score

# %%
sentiment = getSentiments(pytt)

# %%
texts = pd.DataFrame(pytt.text)

# %%
sentimentscore = pd.DataFrame.from_dict(sentiment)
sentimentscore
# Out:
#        neg    neu    pos  compound
# 0    0.000  1.000  0.000    0.0000
# 1    0.000  0.959  0.041    0.2960
# 2    0.000  0.970  0.030    0.2960
# 3    0.000  0.943  0.057    0.7506
# 4    0.000  0.889  0.111    0.9370
# ..     ...    ...    ...       ...
# 589  0.051  0.797  0.152    1.0000
# 590  0.051  0.797  0.152    1.0000
# 591  0.051  0.797  0.152    1.0000
# 592  0.051  0.797  0.152    1.0000
# 593  0.051  0.797  0.152    1.0000
#
# [594 rows x 4 columns]

# %%
tweetscore = pd.concat([texts,sentimentscore],axis=1)

# %%
tweetscore
# Out:
#                                                   text    neg    neu    pos  \
# 0    RT @relyanceai: Action by California Attorney ...  0.000  1.000  0.000
# 1    Join @IDology and @AiteNovarica on October 12t...  0.000  0.959  0.041
# 2    RT @relyanceai: Action by California Attorney ...  0.000  0.970  0.030
# 3    Action by California Attorney General Shows En...  0.000  0.943  0.057
# 4    RT @deanhager: Welcome @ZecOps to the @JamfSof...  0.000  0.889  0.111
# ..                                                 ...    ...    ...    ...
# 589  RT @THORmaximalist: I'm so impressed with @ses...  0.051  0.797  0.152
# 590  RT @nathanbaugh27: Apple surpassed $3.5B in an...  0.051  0.797  0.152
# 591  Data breaches are now part of mainstream repor...  0.051  0.797  0.152
# 592  We are now entering a new era of consumer inte...  0.051  0.797  0.152
# 593  RT @TejasiPanjiar: Very excited to be a part o...  0.051  0.797  0.152
#
#      compound
# 0      0.0000
# 1      0.2960
# 2      0.2960
# 3      0.7506
# 4      0.9370
# ..        ...
# 589    1.0000
# 590    1.0000
# 591    1.0000
# 592    1.0000
# 593    1.0000
#
# [594 rows x 5 columns]

# %% [markdown]
# During this dataframe,
#
#
# text: each tweet which I collected
#
#
# neg: negative sentiment score
#
#
# neutral: neural sentiment score
#
#
# pos: positive sentiment score
#
#
# compound: the overall scores

# %%
tweetscore.to_csv("/Users/yangyilin/Desktop/anly-501-project-YilinYang2000-1/data/00-raw-data/pytweetscore.csv")

# %% [markdown]
# More than this, I would like to define each tweet is negative, neural, positive with compound score in order to the further explorations of users' attitude. At this time, I plan to first, make a definition code to define one sentence is positive, negative or neutural. Then I will use a for loop to bring each sentence a classification and store it in a dataframe.

# %%
def predict_sentiment(sentence):
  '''Function to predict sentiment of a sentence'''
    
  sid = SentimentIntensityAnalyzer()
  sentiment_dict = sid.polarity_scores(sentence)

  # decide sentiment as positive, negative and neutral 
  if sentiment_dict['compound'] >= 0.05 : 
      return ("Positive", round(sentiment_dict['pos']*100, 2))

  elif sentiment_dict['compound'] <= - 0.05 : 
      return ("Negative", round(sentiment_dict['neg']*100, 2))

  else : 
      return ("Neutral", round(sentiment_dict['neu']*100, 2))

# %%
pytt.head()
# Out:
#    Unnamed: 0                   id lang            author_id  \
# 0           0  1574462548027609090   en  1523745650432741377
# 1           1  1574460821073268738   en            377867202
# 2           2  1574459562412822528   en   746303248198303744
# 3           3  1574457040243916800   en  1227402972990099456
# 4           4  1574453153986056192   en   870794599085879298
#
#                  created_at                                               text
# 0  2022-09-26T18:14:58.000Z  RT @relyanceai: Action by California Attorney ...
# 1  2022-09-26T18:08:06.000Z  Join @IDology and @AiteNovarica on October 12t...
# 2  2022-09-26T18:03:06.000Z  RT @relyanceai: Action by California Attorney ...
# 3  2022-09-26T17:53:05.000Z  Action by California Attorney General Shows En...
# 4  2022-09-26T17:37:38.000Z  RT @deanhager: Welcome @ZecOps to the @JamfSof...

# %% [markdown]
# Use the for loop to give each sentence a classification whether it is positive, negative or nutural and use append() function to build a dictionary of result

# %%
result = [] 
for i in pytt.text:
    result.append(predict_sentiment(i))

# %% [markdown]
# Convert dictionary to dataframe and combine this result with text dataframe. At that time, rename the column name in order to make the dataframe easier to understand.

# %%
sentimentresult = pd.DataFrame.from_dict(result)
tweetresult = pd.concat([texts,sentimentresult],axis=1)

tweetresult.rename(columns={0:'result'},inplace=True)
tweetresult.rename(columns={1:'scores'},inplace=True)

# %%
tweetresult
# Out:
#                                                   text    result  scores
# 0    RT @relyanceai: Action by California Attorney ...   Neutral   100.0
# 1    Join @IDology and @AiteNovarica on October 12t...  Positive     6.6
# 2    RT @relyanceai: Action by California Attorney ...   Neutral   100.0
# 3    Action by California Attorney General Shows En...  Positive    10.7
# 4    RT @deanhager: Welcome @ZecOps to the @JamfSof...  Positive    34.6
# ..                                                 ...       ...     ...
# 589  RT @THORmaximalist: I'm so impressed with @ses...  Positive    40.4
# 590  RT @nathanbaugh27: Apple surpassed $3.5B in an...  Negative    14.4
# 591  Data breaches are now part of mainstream repor...  Positive     7.2
# 592  We are now entering a new era of consumer inte...  Positive    11.2
# 593  RT @TejasiPanjiar: Very excited to be a part o...  Positive    10.9
#
# [594 rows x 3 columns]

# %% [markdown]
# ##### Export the dataframe to csv file

# %%
tweetresult.to_csv("/Users/yangyilin/Desktop/anly-501-project-YilinYang2000-1/data/00-raw-data/pytweetresult.csv")

# %% [markdown]
# ## Part2 Twitter API in R

# %% [markdown]
# For R API, I used twitter to scratch keywords like "instagram, tiktok, youtube, facebook" to scratch users' attitudes about these platforms.

# %%
library(selectr)
library(rvest)
library(xml2)
library(wordcloud2) # for generating really cool looking wordclouds
library(tm) # for text minning
library(dplyr) # loads of fun stuff including piping
library(ROAuth)
library(jsonlite)
library(httpuv)
library("tm")
library("SnowballC")
library("wordcloud")
library("RColorBrewer")
suppressWarnings(expr)#ignore warning
options(warn=-1)
# Out:
# Loading required package: NLP
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: RColorBrewer
# function (expr)
# {
#     enexpr(expr)
# }
# <bytecode: 0x7f9761dad6a8>
# <environment: namespace:rlang>

# %%
TweetsDF <- read.csv("/Users/yangyilin/Desktop/anly-501-project-YilinYang2000-1/data/00-raw-data/tweetinr.csv")

# %% [markdown]
# ##### Do text transformation for the dataframe
# Take a glimpse of the dataframe, there is a lot of punctuation that is totally not useful for me to count the future frequency. As a result, I used corpus() to normalizing and tokenizing the dataset, then I use tm_map to remove punctuations like "/","@",etc. More than this, because there are a lot of urls, numbers, white space, and highercase in the text. I decided to remove them all because they will afffect my results. So I cleaned the data as below:

# %%
FName = "~/Desktop/wemediaexample.txt"
MyFile <- file(FName)
cat(unlist(TweetsDF), " ", file=MyFile, sep="\n")
close(MyFile)

# %%
twittertext = Corpus(VectorSource(TweetsDF$text))
toSpace = content_transformer(
              function (x, pattern)
              gsub(pattern, " ", x))
twittertext1 = tm_map(twittertext, toSpace, "/")
twittertext1 = tm_map(twittertext, toSpace, "@")
twittertext1 = tm_map(twittertext, toSpace, "#")
twittertext1 = tm_map(twittertext1, content_transformer(tolower))
twittertext1 = tm_map(twittertext1, removeNumbers)
twittertext1 = tm_map(twittertext1, stripWhitespace)
removeURL <- function(x) gsub("http[[:alnum:]]*", "", x)
twittertext1 = tm_map(twittertext, removeURL)
strwrap(twittertext1)
# Out:
#   [1] "c(\"RT @SeanBurkeShow: I am begging BEGGING the people of Tik Tok to"
#   [2] "learn what POV means.\", \"RT @SkylieJ_: I posted my mom wearing my brand"
#   [3] "on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I"
#   [4] "posted my mom wearing my brand on tik tok and she went viral 🤩"
#   [5] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
#   [6] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT"
#   [7] "@CascadeIceWater: #GIVEAWAY ALERT! It’s officially fall, and we are"
#   [8] "feelin’ it! To win free Cascade Ice, “like” this tweet + reply with…\","
#   [9] "\"RT @10KDunkin: The period uhhh girl from tik tok jus got signed , dat"
#  [10] "jus stamped music isn’t bout talent no more its bout tik tok views\","
#  [11] "\"RT @SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
#  [12] "viral 🤩 ://t.co/XiuiTtPWGV\", \"Meta makes it easier to switch between"
#  [13] "Facebook and Instagram accounts - CNBC ://t.co/PzAY7N4dBr via"
#  [14] "@GoogleNews \\n😆\", \"RT @longliveswift22: Imagine being on Tik tok"
#  [15] "making the stupidest theory videos that make NO fucking sense\", \"RT"
#  [16] "@alOakhwan: It's like when women buy a really ugly pug and dress it up"
#  [17] "in gаy little outfits for tik tok\", \"RT @HermesIyele: Awwwwww, Hermes"
#  [18] "drops a heartfelt message to the fans on WhatsApp groups.\\n\\nTwitter,"
#  [19] "Facebook and Instagram people wait for…\", \"RT @SkylieJ_: I posted my"
#  [20] "mom wearing my brand on tik tok and she went viral 🤩"
#  [21] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
#  [22] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @BarefootCampus:"
#  [23] "It's time for another #barefoot6packgiveaway !!!\\nHow to enter:"
#  [24] "\\n⚡Follow us\\n⚡Like this tweet\\n⚡Retweet this tweet\\n\\nWinner…\", \"RT"
#  [25] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
#  [26] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my"
#  [27] "brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"BEST"
#  [28] "CENTER ON 2K23 - !Twitter !Instagram !TikTok !YouTube"
#  [29] "\\n\\n://t.co/Oo0LhH5JAK ://t.co/glzKQcSaWM\", \"RT @SkylieJ_: I posted my"
#  [30] "mom wearing my brand on tik tok and she went viral 🤩"
#  [31] "://t.co/XiuiTtPWGV\", \"My #socials for people to reach out to me and"
#  [32] "#follow my other #content. This contains my #Twitter, #Instagram,…"
#  [33] "://t.co/v0Coov8B1n\", \"@ShiLLin_ViLLian Your being a @barkmeta now on"
#  [34] "Tik Tok 🤦‍♂️\", \"RT @SkylieJ_: I posted my mom wearing my brand on tik"
#  [35] "tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"Awwwwww, Hermes drops a"
#  [36] "heartfelt message to the fans on WhatsApp groups.\\n\\nTwitter, Facebook"
#  [37] "and Instagram people w… ://t.co/HqvUWqyfPE\", \"RT @SkylieJ_: I posted my"
#  [38] "mom wearing my brand on tik tok and she went viral 🤩"
#  [39] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
#  [40] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"@lastSonOfCy Wait"
#  [41] "nvm one lady on tik tok said so\", \"RT @FarrisFlagg: Watching"
#  [42] "#TheJenniferHudsonShow on @FOXLA! Weekdays at 12pm! #ImWithJHud! Follow"
#  [43] "@JHudShow on @Twitter, @instagram, @faceb…\", \"RT @bengaljims_BTR: We’re"
#  [44] "partnering w @goldstarchili, Official Chili of the #Bengals, to give 2"
#  [45] "tix to TNF vs #Dolphins \\n\\nTO ENTER follow…\", \"@_danyellb Tik Tok"
#  [46] "showed me enough for the day, that’s why I don’t be on there lmao\","
#  [47] "\"@kay_t12 @MetaNewsroom @facebook @instagram Support services will only"
#  [48] "take you round in circles without offering a… ://t.co/T8r01UEDou\","
#  [49] "\"Contacting their support is totally pointless, because they are not"
#  [50] "going to reply. You can inbox us now we’re fast… ://t.co/Gs9biFqRrw\","
#  [51] "\"@eclipsethis2003 First time I have seen a tik tok of a chick with red"
#  [52] "hair crying and it made sense.\\n\\nThis is the s… ://t.co/hU4qglOuVK\","
#  [53] "\"Meet #TheTeamBehindYourTeam 😎⁠\\n⁠\\n💥 Hi! I am DJ, Account Manager at"
#  [54] "Creatively Disruptive. 💥\\n⁠\\nBuilding a strong rel…"
#  [55] "://t.co/1fm3jZSRwu\", \"RT @kyylareneee: Not this girl on tik tok wearing"
#  [56] "my brand and it got a million likes??)!)?  Hello??!)?"
#  [57] "://t.co/SwVMVA2qKm\", \"@ChuckCallesto @PeacefulConserv Reparations?"
#  [58] "Really? Cause I’m seeing all these tik tok videos lately of black grou…"
#  [59] "://t.co/kYmoZ2BflE\", \"RT @Knwupdate: ᯤ 》IG : lipsmagazine •"
#  [60] "26.09.22\\n\\n🪄 ://t.co/9sYjeCcELw\\n\\nᯤ 》FB : LIPS MAGAZINE •"
#  [61] "26.09.22\\n\\n🪄 ://t.co/1U6r8EhIAb\\n\\n💬 P…\", \"@HuaweiZA FACEBOOK"
#  [62] "\\nTIKTOK \\nINSTAGRAM \\nTWITTER \\nWHATSAPP \\n#HUAWEI #HUAWEIAppGallery"
#  [63] "\\nMy 5 favourites on my HUAWEI A… ://t.co/xuSzkDkEu2\", \"RT @SkylieJ_: I"
#  [64] "posted my mom wearing my brand on tik tok and she went viral 🤩"
#  [65] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
#  [66] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I"
#  [67] "posted my mom wearing my brand on tik tok and she went viral 🤩"
#  [68] "://t.co/XiuiTtPWGV\", \"RT @LilMoGh: My phone reach Facebook and"
#  [69] "instagram all\\nEverybro dey claim ownership 😂😂😂😂😂\", \"RT @SkylieJ_:"
#  [70] "I posted my mom wearing my brand on tik tok and she went viral 🤩"
#  [71] "://t.co/XiuiTtPWGV\", \"RT @tvasquezz: Saw a tik tok that said if you’re"
#  [72] "not being treated the way you would want your bestfriend to be treated,"
#  [73] "then leave. SOOOO…\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
#  [74] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I"
#  [75] "posted my mom wearing my brand on tik tok and she went viral 🤩"
#  [76] "://t.co/XiuiTtPWGV\", \"RT @KaiS2com: WATERBOMB 2022 AFTER MOVIE\\n\\nKAI"
#  [77] "cut ver.\\n\\nTimetable youtube channel \\n🔗"
#  [78] "://t.co/BDkJiTuXSG\\n\\nwaterbomb_official instagram…\", \"RT @SkylieJ_: I"
#  [79] "posted my mom wearing my brand on tik tok and she went viral 🤩"
#  [80] "://t.co/XiuiTtPWGV\", \"That tik tok sound “mm mmm mm today DRAINED me”"
#  [81] "has been playing on repeat in my head.\", \"i pray i end up with someone"
#  [82] "that likes making tik tok videos with me🥺\\ni’ll just be like"
#  [83] "“babeeeee, let’s make a ti… ://t.co/MF4xqjDnHI\", \"RT @SkylieJ_: I"
#  [84] "posted my mom wearing my brand on tik tok and she went viral 🤩"
#  [85] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
#  [86] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I"
#  [87] "posted my mom wearing my brand on tik tok and she went viral 🤩"
#  [88] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
#  [89] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I"
#  [90] "posted my mom wearing my brand on tik tok and she went viral 🤩"
#  [91] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
#  [92] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @LilMoGh: My"
#  [93] "phone reach Facebook and instagram all\\nEverybro dey claim ownership"
#  [94] "😂😂😂😂😂\", \"I wish i could make a tik tok of how many times snk frk"
#  [95] "has fixed my car 💀\", \"Instagram,TikTok,YouTube. Everywhere is popping"
#  [96] "👌👌👌🔥\", \"RT @HughesDirect: Enter our latest prize draw to #WIN a"
#  [97] "@BekoUK AeroPerfect Oven!\\nThis is a multi-platform prize draw and can"
#  [98] "be entered on…\", \"Official account\\nInstagram"
#  [99] "@orihfir\\n://t.co/0s6dM68vNj\\n\\nFacebook \\n://t.co/IkqspyWXSB…"
# [100] "://t.co/MktexvTlGN\", \"#DHHSC #ValleyDeafFestival #VDF2022 #PaymentPlan"
# [101] "#VDFTickets \\n\\n*STILL ACCEPTING MONTHLY PAYMENTS FOR VDF TICKET(S)*…"
# [102] "://t.co/IQM5vnUv8t\", \"RT @10KDunkin: The period uhhh girl from tik tok"
# [103] "jus got signed , dat jus stamped music isn’t bout talent no more its"
# [104] "bout tik tok views\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [105] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I"
# [106] "posted my mom wearing my brand on tik tok and she went viral 🤩"
# [107] "://t.co/XiuiTtPWGV\", \"Just listened to phone music for the first time"
# [108] "not through a tik tok vid and it was a whole mood booster 👁👄👁👌🏽\","
# [109] "\"Just saw someone on tik tok say that they have a book club with their"
# [110] "friends and now I’m crying cause my friends don’t read\", \"RT @SkylieJ_:"
# [111] "I posted my mom wearing my brand on tik tok and she went viral 🤩"
# [112] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [113] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I"
# [114] "posted my mom wearing my brand on tik tok and she went viral 🤩"
# [115] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [116] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SeanBurkeShow:"
# [117] "I am begging BEGGING the people of Tik Tok to learn what POV means.\","
# [118] "\"RT @SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [119] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my"
# [120] "brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT"
# [121] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [122] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @CascadeIceWater: #GIVEAWAY ALERT!"
# [123] "It’s officially fall, and we are feelin’ it! To win free Cascade Ice,"
# [124] "“like” this tweet + reply with…\", \"RT @SkylieJ_: I posted my mom"
# [125] "wearing my brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\","
# [126] "\"RT @SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [127] "viral 🤩 ://t.co/XiuiTtPWGV\", \"INSTAGRAM VS REALITY"
# [128] "://t.co/4CyJMHaMpV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [129] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I"
# [130] "posted my mom wearing my brand on tik tok and she went viral 🤩"
# [131] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [132] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @JubilationsArt:"
# [133] "@drunkenfix Custom World legit robbing artists and altering the art to"
# [134] "remove signatures woww. they have a facebook and…\", \"RT @SkylieJ_: I"
# [135] "posted my mom wearing my brand on tik tok and she went viral 🤩"
# [136] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [137] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"://t.co/QQsSqC14dN"
# [138] "@ Suffolk County, New York ://t.co/35cF0wjH6k\", \"he got no instagram so"
# [139] "he better post me on facebook idc\", \"RT @SkylieJ_: I posted my mom"
# [140] "wearing my brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\","
# [141] "\"RT @SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [142] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my"
# [143] "brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT"
# [144] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [145] "viral 🤩 ://t.co/XiuiTtPWGV\", \"Photo by my friend: @ZaiNeganCaryl for"
# [146] "@wwwbigbaldhead #DarylDixon's new #TheWalkingDead @WalkingDead_AMC spin"
# [147] "off… ://t.co/SeFec0k13M\", \"guys… That tik tok trend is coming back…\","
# [148] "\"RT @ZssBecker: Its Monday. It's 4am.\\n\\nGet shit done. Get in the gym."
# [149] "Don't do dumb shit.\\n\\nThere's absolutely no one stopping you from"
# [150] "getti…\", \"RT @SteveBrodt: 🚨EPISODE 4 TONIGHT🚨\\n\\nDon’t forget to"
# [151] "share this link with #Alone 👇🏻👇🏻\\n://t.co/uPtcOhIjL9\\n\\nAnd comment"
# [152] "this weeks phras…\", \"They really trying to clown Angela Simmons little"
# [153] "Tik Tok like some of us don’t find that pretty goofiness sexy😂\", \"RT"
# [154] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [155] "viral 🤩 ://t.co/XiuiTtPWGV\", \"if you're consuming content from money"
# [156] "twitter instead of scrolling on tik tok you're already in the 1%\","
# [157] "\"Should I finally give into China backed Tik Tok? ://t.co/fOxfx7AMRY\","
# [158] "\"I posted a tik tok of my cat and within 5mins it’s been viewed 577"
# [159] "times 😒\", \"Follow me on tiktok and Instagram@hey_i_am_2kay28 for more"
# [160] "videos ♊#2kay28 #viral #viral #like #memes #follow…"
# [161] "://t.co/BVZx51zja9\", \"RT @marcylaycelle: Hello Friends - Two Winners"
# [162] "will be selected for a giveaway of a red tulip wreath.\\n\\nMultiple"
# [163] "Entries BY:\\n💜Follow Me on T…\", \"I’m fascinated by the fact tik tok"
# [164] "has allowed us all to be taken away from reality and everything is off"
# [165] "limits. J… ://t.co/Uxa2Vy0fDV\", \"One of 25 winners for using twitter,"
# [166] "Facebook and Instagram? Can't believe my luck! ://t.co/JaR3Of2ddP\", \"RT"
# [167] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [168] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @Syned_Gaming: SWS-10 Headshot"
# [169] "farming Part 2\\n\\n#twitch #youtube #video #supportsmallstreamers"
# [170] "#twitter #gaming #twitchstreamer #twitchtv…\", \"New tik tok for other"
# [171] "non-apex content 😌 drop a follow 💋 ://t.co/Fp1Sx7v7xq\", \"RT"
# [172] "@HughesDirect: Don't forget to enter our prize draw to #WIN a @BekoUK"
# [173] "Oven!\\nThis is a multi-platform prize draw and can be entered on Fa…\","
# [174] "\"RT @SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [175] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @HughesDirect: Enter our prize draw"
# [176] "to #WIN a @BekoUK AeroPerfect Oven! \\nThis is a multi-platform prize"
# [177] "draw and can be entered on Faceb…\", \"the tik tok girlies be putting me"
# [178] "onto all the good amazon finds. these cargo pants I got are saur cute\","
# [179] "\"RT @SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [180] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @zxpriel: i’m catching on to these"
# [181] "“brands” on tik tok im starting to think majority of them niggas"
# [182] "scammers on the side or sum\", \"They have Tiktok, Twitter, YouTube and"
# [183] "Instagram. They also have a fan community that you can join on an app"
# [184] "name F… ://t.co/dlM1Rd68Bl\", \"tired of seeing those people on tik tok"
# [185] "unbox a txt album and are dissapointed in who they pull like\", \"Nothing"
# [186] "I just printed out five articles to start annotating and been on tik"
# [187] "tok scrolling\", \"RT @WineBeyond: 📣 🥃 ENTER TO WIN two tickets to an"
# [188] "exclusive Forty Creek Whisky tasting led by Master Blender, Bill"
# [189] "Ashburn!\\n\\nCalgary follo…\", \"RT @basim_basim_bas: If you feel the need"
# [190] "to, please feel free to leave the ST fandom! Dangerous shit is"
# [191] "happening. Moving over to ST Tumbl…\", \"Someone on Tik Tok said AKA made"
# [192] "Burna Boy 🤣🤣 bruh that stint he had making music with them almost"
# [193] "killed his caree… ://t.co/U1q9oBTbiL\", \"RT @Marketineando: News:"
# [194] "@Cre8tiveMarComs: 'Meta rolls out FB Reels to over 150"
# [195] "countries.\\n://t.co/ONyEm3Hpmi \\n\\n#socialmedia #marketin…\", \"RT"
# [196] "@Ashh_K21: Small Accounts Matter ❕RT • GAIN FAST wirh us #BBN"
# [197] "✔️🥦,%🍝”%\\nLet's start then tik tok tik tok\\n\\n@Ashh_K21 \\n@ap92X"
# [198] "\\n@Azix103 \\n@S…\", \"RT @ap92X: Small Accounts Matter ❕RT • GAIN FAST"
# [199] "wirh us #BBN ✔️🥦,\\nLet's start then tik tok tik tok\\n@Aln_m6"
# [200] "@NZPTI_\\n@_jan00 @khg_82\\n@BAA_WA…\", \"how tf do you make a tik tok with"
# [201] "an audio but then use your own videos audio after like 2 seconds\","
# [202] "\"Brands need to stop thinking they have to do comedy/meme trends on Tik"
# [203] "Tok, it’s not working 😬\", \"RT @LisaJemide: I need tik tok to be funny"
# [204] "again pls not everyday how to deal with a break up/ how to tap into"
# [205] "your feminine energy tik tok…\", \"@AZmilitary1 hei AZ, thanks for"
# [206] "helping people understand that RU is the controlled opposition of the"
# [207] "\\\"US\\\" Empire. 😂 tik tok\", \"Like Us on #Instagram:"
# [208] "://t.co/xYIocjIHp0\\n\\nLike Us on #Facebook: ://t.co/a3SeUu3FoC \\n\\nOur"
# [209] "#YouTube channe… ://t.co/qXmonjXDep\", \"RT @SkylieJ_: I posted my mom"
# [210] "wearing my brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\","
# [211] "\"26 September 2022 - @joejonas via TikTok, Instagram Reels, Twitter and"
# [212] "Facebook \\n“The future of vision correction i… ://t.co/BuLN9P3xwA\", \"RT"
# [213] "@experienceennis: Last Friday, @CECultureNight was a true gem! Thanks"
# [214] "to everyone that made it happen &amp; to everyone that came to enjoy"
# [215] "a…\", \"@JeannetheQueen1 @kissingtheroach @ThirdCultureMum @Longjacket2"
# [216] "@WillMeyerPA @AZ_Brittney @_NicoleNonya She’s a rea…"
# [217] "://t.co/wDbF8NORJz\", \"RT @ap92X: Small Accounts Matter ❕RT • GAIN FAST"
# [218] "wirh us #BBN ✔️🥦,\\nLet's start then tik tok tik"
# [219] "tok\\n@S_BJ512💯\\n@Aln_m6 @Q_261\\n@_jan00 @mapj2…\", \"RT @umuchiukwu: ESN"
# [220] "have no WhatsApp group, no signal group, no Instagram group, have no"
# [221] "Facebook group\\n\\nMazi @ChinasaNworu on Radio Biafra…\", \"RT"
# [222] "@progresswiszy: ESN have no WhatsApp group, no signal group, no"
# [223] "Instagram group, have no Facebook group\\n\\nMazi @ChinasaNworu on Radio"
# [224] "Bia…\", \"RT @ap92X: Small Accounts Matter ❕RT • GAIN FAST wirh us #BBN"
# [225] "✔️🥦,\\nLet's start then tik tok tik tok\\n@Aln_m6 @NZPTI_\\n@_jan00"
# [226] "@mapj21\\n@BAA_WA…\", \"RT @Cau7ioN: idk who needs to hear this but"
# [227] "“grinding” 10 hour streams without making content on tik tok and"
# [228] "YouTube is the reason you’re n…\", \"RT @ShelleyACook: Super cool,"
# [229] "@AMCMBChiefs shared my @WinnipegNews column on Facebook and Instagram"
# [230] "today— they included the pic with @cee_…\", \"What is wrong with this"
# [231] "rollout? It’s so fun!! We got the cool collectible cd/vinyl clock,"
# [232] "she’s got a fun little t… ://t.co/qEWlmI9593\", \"@xomilaharper Seeing"
# [233] "you on tik tok and coming to your Twitter, the tone is completely"
# [234] "different\", \"RT @TyierraG: tik tok &amp; twitter is all the"
# [235] "entertainment i need stg cause the ppl in this world are"
# [236] "FUNNY.!😭😭😭😭\", \"RT @OmoteBiafra: ESN have no WhatsApp group, have no"
# [237] "signal group, have no Instagram group,have no Facebook group.\\n\\n Mazi"
# [238] "Chinasa Nworu\", \"RT @ZssBecker: Its Monday. It's 4am.\\n\\nGet shit done."
# [239] "Get in the gym. Don't do dumb shit.\\n\\nThere's absolutely no one"
# [240] "stopping you from getti…\", \"RT @Marketineando: News: @Cre8tiveMarComs:"
# [241] "'Meta rolls out FB Reels to over 150 countries.\\n://t.co/ONyEm3Hpmi"
# [242] "\\n\\n#socialmedia #marketin…\", \"RT @SkylieJ_: I posted my mom wearing my"
# [243] "brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT"
# [244] "@AlaricAloor: ://t.co/PmZfWobTKw\\n\\nAnd now a class action lawsuit"
# [245] "against FB 👇🏾\\n\\n@MiaD @hessiejones @roxananasoi @psb_dc"
# [246] "@DrJDroogha…\", \"RT @basim_basim_bas: If you feel the need to, please"
# [247] "feel free to leave the ST fandom! Dangerous shit is happening. Moving"
# [248] "over to ST Tumbl…\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [249] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"My fav is when"
# [250] "someone on tik tok is like “buy this and spray paint for this item” …"
# [251] "where am I going to spray pain… ://t.co/GJQmtf5gK1\", \"User_lacking on"
# [252] "tik tok that’s Me\", \"RT @10KDunkin: The period uhhh girl from tik tok"
# [253] "jus got signed , dat jus stamped music isn’t bout talent no more its"
# [254] "bout tik tok views\", \"Telegram link:://t.co/uUk6Bz13kK\\n\\nInstagram"
# [255] "link:://t.co/LrNwj8DBTl\\n\\nFacebook link:… ://t.co/5FMqFWcQex\", \"RT"
# [256] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [257] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my"
# [258] "brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"We have"
# [259] "helped alot of people Recover their lost/ Hacked Account and Wallets"
# [260] "etc\\n\\nLet me help you recover that your… ://t.co/vDEFEobeaS\", \"Whil(e)"
# [261] "there are many social media scheduling tools out there, we highly"
# [262] "recommend using the native Meta Planner f… ://t.co/83B90qb69F\", \"RT"
# [263] "@NjimeziChidi: ESN have no WhatsApp group, no signal group, no"
# [264] "Instagram group, have no Facebook group\\n\\nMazi @ChinasaNworu on Radio"
# [265] "Biaf…\", \"RT @JoeGalliNews: Don't miss a single episode! Subscribe to"
# [266] "the NWA on YouTube today!\\n📺 ://t.co/nf11XsVhvw\\n\\nBe sure to follow"
# [267] "us on al…\", \"RT @kyylareneee: Not this girl on tik tok wearing my brand"
# [268] "and it got a million likes??)!)?  Hello??!)? ://t.co/SwVMVA2qKm\", \"tik"
# [269] "tok has a bereal feature now???? lmao\", \"RT @seonho_myhihyu: 220925"
# [270] "kimsda IG update:\\n://t.co/2S2MFeOWHY\\n\\n#️⃣PreferredVideo\\nActor"
# [271] "#KimSeonho who acted as Joe Simpson, whom we…\", \"RT @SkylieJ_: I posted"
# [272] "my mom wearing my brand on tik tok and she went viral 🤩"
# [273] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [274] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SeanBurkeShow:"
# [275] "I am begging BEGGING the people of Tik Tok to learn what POV means.\","
# [276] "\"RT @SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [277] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my"
# [278] "brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT"
# [279] "@keepit100boxin2: TBE\\n\\nFollow keepit100boxing on IG and Tik Tok and"
# [280] "YouTube ://t.co/dYujj25M2V\", \"RT @SkylieJ_: I posted my mom wearing my"
# [281] "brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"the grip"
# [282] "that hidden valley ranch seasoning packets and cream cheese (together"
# [283] "or separate) have on white people on Tik Tok is insane\", \"RT @SkylieJ_:"
# [284] "I posted my mom wearing my brand on tik tok and she went viral 🤩"
# [285] "://t.co/XiuiTtPWGV\", \"RT @TeeChereaa: My favorite trend on Tik Tok"
# [286] "right now 🥵 ://t.co/4KQ5C5ZDpi\", \"RT @SkylieJ_: I posted my mom"
# [287] "wearing my brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\","
# [288] "\"RT @TeeChereaa: My favorite trend on Tik Tok right now 🥵"
# [289] "://t.co/4KQ5C5ZDpi\", \"@davenewworld_2 I'm waiting for that bear to post"
# [290] "its Tik Tok about being harassed by a male Karen.\", \"RT @estudio_dlc:"
# [291] "SERVICIOS ONLINE 🌐 ://t.co/LoV67ybs2y ✉️ info@estudio-dlc.com📍NORDELTA"
# [292] "://t.co/KDxhvGdxAP 📍C.A.B.A. ://t.co…\", \"RT @SkylieJ_: I posted my mom"
# [293] "wearing my brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\","
# [294] "\"Not this girl on tik tok wearing my brand and it got a million"
# [295] "likes??)!)?  Hello??!)? ://t.co/SwVMVA2qKm\", \"I don’t know what the"
# [296] "gifts mean on tik tok but I love sending them\", \"RT @SkylieJ_: I posted"
# [297] "my mom wearing my brand on tik tok and she went viral 🤩"
# [298] "://t.co/XiuiTtPWGV\", \"just finished editing a tik tok that is just tew"
# [299] "gooodddd 😭😭😭 but I’m gonna wait for halloween first to post it"
# [300] "😭😭😭\", \"RT @HughesDirect: Don't forget to enter our prize draw to"
# [301] "#WIN a @BekoUK Oven!\\nThis is a multi-platform prize draw and can be"
# [302] "entered on Fa…\", \"@usman__haruna I ask again, who later won the aero"
# [303] "plane, the person suppose get Twitter handle, Instagram or Faceb…"
# [304] "://t.co/5lIC8SeiGo\", \"RT @sophdoeslife: no joke I have had 6 pregnancy"
# [305] "announcements, 3 births and 2 engagements on my facebook and instagram"
# [306] "feeds in the past 2…\", \"RT @SkylieJ_: I posted my mom wearing my brand"
# [307] "on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"@CallumTFFTT"
# [308] "@FieryBreadman Bro that’s you? Goddam had I known this I would have"
# [309] "followed u a while ago. Cuz I follow u on tik tok\", \"Tik tok videos"
# [310] "that are made to be heartfelt where someone gets released after 30+"
# [311] "years are crazy that mf probably… ://t.co/03MGOmXXk6\", \"RT @SiboKaur:"
# [312] "Highest Instagram Engagement of Last Week 6.86%\\nHighiest Twitter"
# [313] "Engagement of Last Week, 4.84%\\nMost Search YouTube Celebri…\", \"RT"
# [314] "@LilMoGh: My phone reach Facebook and instagram all\\nEverybro dey claim"
# [315] "ownership 😂😂😂😂😂\", \"@Troyttod @aginnt @TonyP12490831 Look how"
# [316] "business model of Instagram, Facebook &amp; Hollywood etc works.\\n\\nThe"
# [317] "money m… ://t.co/pk36Uni38U\", \"RT @SkylieJ_: I posted my mom wearing my"
# [318] "brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT"
# [319] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [320] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @Yellow_stone3: @Antoo_Ovalle El tik"
# [321] "tok de \\\"I fuking hate my life everything sucks ✨ there's a tiny cow"
# [322] "✨omg my life is amazing I love…\", \"Guy on tik tok said he had to tell"
# [323] "his WIFE that sometimes it’s hard being her husband bc she loves him"
# [324] "too much an… ://t.co/GhSbXW4R2P\", \"RT @MeganTroy7: Help get the word"
# [325] "out fann(e)dom. Let the Gentleman Jack fans on Facebook &amp; Instagram"
# [326] "know how much fun every day is with t…\", \"RT @naazkijaan: Highiest"
# [327] "Instagram Engagement of Last Week 6.86%\\nHighiest Twitter Engagement of"
# [328] "Last Week, 4.84%\\nMost Search YouTube Cele…\", \"TBE\\n\\nFollow"
# [329] "keepit100boxing on IG and Tik Tok and YouTube ://t.co/dYujj25M2V\", \"RT"
# [330] "@Doll_VT: Sorry I'm late with schedule, but here, come watch me play"
# [331] "video games badly while being hot this week!\\n\\nTwitch -&gt; ://t.c…\","
# [332] "\"RT @GrayFrequency: ✅#DeadbyDaylight\\n✅ Survivor Memes\\n✅"
# [333] "Huntress\\n\\n#DeadbyDaylgiht #dbd #gaming #pcgaming #funny #Memes"
# [334] "#YouTube #TikTok #ins…\", \"RT @MewlionsUSA: IG &amp; FB Updates |"
# [335] "metro.society / METROSOCIETY\\n9.26.2022\\n\\nShare, Like and Comment"
# [336] "Here\\n➡️://t.co/aeEDAADPI9\\n➡️:/…\", \"@TheSun The funny thing about this"
# [337] "is that the sun propagandist will get dirty before someone goes to jail"
# [338] "by a dirty car. tik tok\", \"RT @BarefootCampus: It's time for another"
# [339] "#barefoot6packgiveaway !!!\\nHow to enter: \\n⚡Follow us\\n⚡Like this"
# [340] "tweet\\n⚡Retweet this tweet\\n\\nWinner…\", \"@deaccolin Go on tik tok and"
# [341] "search “MW2 Proximity Chat” 😂😂 shits dope\", \"RT @umuchiukwu: ESN have"
# [342] "no WhatsApp group, no signal group, no Instagram group, have no"
# [343] "Facebook group\\n\\nMazi @ChinasaNworu on Radio Biafra…\", \"RT @SkylieJ_:"
# [344] "I posted my mom wearing my brand on tik tok and she went viral 🤩"
# [345] "://t.co/XiuiTtPWGV\", \"I’ve just watched a tik tok of someone unbox the"
# [346] "Ariana Grande My Everything lavender clear split vinyl and full on…"
# [347] "://t.co/YctjtcitXE\", \"RT @OmoteBiafra: ESN have no WhatsApp group, have"
# [348] "no signal group, have no Instagram group,have no Facebook group.\\n\\n"
# [349] "Mazi Chinasa Nworu\", \"#nowplaying on Mintwave Radio mint_01 #alexa"
# [350] "#streema #Scotland #echo #global #uk #instagram #tiktok #twitter…"
# [351] "://t.co/rYzW30vqG7\", \"@kasscib omg i just saw a tik tok about this."
# [352] "hotel girl for life. you can’t beat the free breakfast !!\", \"RT"
# [353] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [354] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SeanBurkeShow: I am begging BEGGING"
# [355] "the people of Tik Tok to learn what POV means.\", \"RT @SkylieJ_: I"
# [356] "posted my mom wearing my brand on tik tok and she went viral 🤩"
# [357] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [358] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT"
# [359] "@NCTDREAMrecords: Social Media Growth 09.18~09.24\\n\\nTwitter\\n➯"
# [360] "@NCTsmtown_DREAM\\n\\nSpotify\\n➯ ://t.co/iJ4KeV2lKp\\n\\nInstagram\\n➯"
# [361] "://t.…\", \"RT @SkylieJ_: I posted my mom wearing my brand on tik tok and"
# [362] "she went viral 🤩 ://t.co/XiuiTtPWGV\", \"Another meme @instagram removed"
# [363] "@Meta @OversightBoard @facebook ://t.co/FJ3WAR7SKP\", \"RT @MewlionsUSA:"
# [364] "IG &amp; FB Updates | ch7hd_entertainment / Ch7HD"
# [365] "Entertainment\\n9.26.2022\\n\\nShare, Like and Comment"
# [366] "Here:\\n➡️://t.co/69y5T5…\", \"RT @Danno_GSD: I’m impatient so I’m posting"
# [367] "this here before it goes on tik tok ://t.co/86guFUl2QC\", \"RT @SkylieJ_:"
# [368] "I posted my mom wearing my brand on tik tok and she went viral 🤩"
# [369] "://t.co/XiuiTtPWGV\", \"@HotepJesus If Covid was a public health"
# [370] "emergency worthy of shutting down the economy, schools, and churches..."
# [371] "Th… ://t.co/lpDhipo66R\", \"have not been able to go longer than an hour"
# [372] "without rewatching that hatsune miku tik tok\", \"RT @SteveBrodt:"
# [373] "🚨EPISODE 4 TONIGHT🚨\\n\\nDon’t forget to share this link with #Alone"
# [374] "👇🏻👇🏻\\n://t.co/uPtcOhIjL9\\n\\nAnd comment this weeks phras…\", \"RT"
# [375] "@RadioKC: ▂▂▂▂▂▂▂▂▂▂▂▂▂▂\\n#TheWelcomeShow #226 PREMIERE\\n\\n🔊"
# [376] "@BadLlamaBand - Viper\\n\\nNOV 2021 Single\\n\\n🌐 ://t.co/5gMacvQacn\\n📸"
# [377] "://t.…\", \"RT @SkylieJ_: I posted my mom wearing my brand on tik tok and"
# [378] "she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @JoeGalliNews: Don't miss a"
# [379] "single episode! Subscribe to the NWA on YouTube today!\\n📺"
# [380] "://t.co/nf11XsVhvw\\n\\nBe sure to follow us on al…\", \"RT @SkylieJ_: I"
# [381] "posted my mom wearing my brand on tik tok and she went viral 🤩"
# [382] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [383] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I"
# [384] "posted my mom wearing my brand on tik tok and she went viral 🤩"
# [385] "://t.co/XiuiTtPWGV\", \"Let me help you recover that your Hacked"
# [386] "Facebook, Instagram, Twitter Pinterest, Gmail, Snapchat etc....…"
# [387] "://t.co/4aW9dqzgg2\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [388] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"A meme @instagram"
# [389] "removed @Meta @OversightBoard @facebook ://t.co/GM2MEeSa3r\", \"RT"
# [390] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [391] "viral 🤩 ://t.co/XiuiTtPWGV\", \"News: @Cre8tiveMarComs: 'Meta rolls out"
# [392] "FB Reels to over 150 countries.\\n://t.co/ONyEm3Hpmi \\n\\n#socialmedia…"
# [393] "://t.co/eCMGDaw7bJ\", \"@binance WHO SHOULD WE FOLLOW: Me 🤗\\nWHY:"
# [394] "Because I'm a Binance affiliate and i support the community and follow"
# [395] "all… ://t.co/BKkIViMJP1\", \"RT @NjimeziChidi: ESN have no WhatsApp"
# [396] "group, no signal group, no Instagram group, have no Facebook"
# [397] "group\\n\\nMazi @ChinasaNworu on Radio Biaf…\", \"RT @SkylieJ_: I posted my"
# [398] "mom wearing my brand on tik tok and she went viral 🤩"
# [399] "://t.co/XiuiTtPWGV\", \"tik tok: someone showing a siren"
# [400] "testing\\ncomment: omg!!!! i thought this was a purge"
# [401] "siren!!!!!😵‍💫😭\\n\\nplease I can’t y’all are so annoying\", \"RT"
# [402] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [403] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my"
# [404] "brand on tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT"
# [405] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [406] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @itsR_A_E: Whose idea was it to"
# [407] "change Tik Tok’s editing section???? I CANNOT STAND IT\", \"This girl on"
# [408] "Facebook always doing tik tok twerks on her story. She always make a"
# [409] "stink face like she's stepping in a fraternity.\", \"RT @buczek_lech:"
# [410] "Share the new #savearmenia action on twitter, facebook, instagram,"
# [411] "whatsapp, telegram, vibe!\\n\\n#savearmenia @serjtankian ht…\", \"RT"
# [412] "@SkylieJ_: I posted my mom wearing my brand on tik tok and she went"
# [413] "viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @LilMoGh: My phone reach Facebook and"
# [414] "instagram all\\nEverybro dey claim ownership 😂😂😂😂😂\", \"She wish her"
# [415] "fans could “Mass Buy” 😂😂😂😂😂😂😂😂😂😂😂😂😂😂\\n\\nHer LABEL has to"
# [416] "“Mass Buy” Radio \\n\\n“Mass Buy” Viral Twitter Acc… ://t.co/qJfvpvbjcz\","
# [417] "\"RT @HughesDirect: Enter our latest prize draw to #WIN a @BekoUK"
# [418] "AeroPerfect Oven!\\nThis is a multi-platform prize draw and can be"
# [419] "entered on…\", \"Spice, Sean Paul, Shaggy - Go Down Deh (Tik Tok Remix"
# [420] "2022) | FAST &amp; FUR... ://t.co/DHV4yQ319n via @YouTube\", \"@Valere_ia"
# [421] "@anesterova2 @AnaGarc12600762 @GangusKhan777 @TibiMagyari @Giobegood"
# [422] "@Freemindgo @Freespe83912197… ://t.co/uynGFF7huy\", \"RT @SkylieJ_: I"
# [423] "posted my mom wearing my brand on tik tok and she went viral 🤩"
# [424] "://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I posted my mom wearing my brand on"
# [425] "tik tok and she went viral 🤩 ://t.co/XiuiTtPWGV\", \"RT @SkylieJ_: I"
# [426] "posted my mom wearing my brand on tik tok and she went viral 🤩"
# [427] "://t.co/XiuiTtPWGV\", \"deleted snap n insta.. gotta stick w my tik tok n"
# [428] "twitter\", \"RT @SkylieJ_: I posted my mom wearing my brand on tik tok"
# [429] "and she went viral 🤩 ://t.co/XiuiTtPWGV\")"
# [430] "list(language = \"en\")"
# [431] "list()"
# <<SimpleCorpus>>
# Metadata:  corpus specific: 1, document level (indexed): 0
# Content:  documents: 250

# %% [markdown]
# ##### Calculate the frequencies of words
# Since I need the results to compare the popularity among each platforms, the frequencies of words will help me to understand which platforms are discussed more among twitter. As a result, I used termdocumentmatrix() to calculate the frequecies each word appears. Then I sort the table in the descending order to see the frequencies more straightforward.

# %%
twittertm = TermDocumentMatrix(twittertext1)
m = as.matrix(twittertm)
v = sort(rowSums(m), 
         decreasing = TRUE)
d = data.frame(word = names(v),
               freq = v)
head(d, 10)
# Out:
#                    word               freq
# tik                tik                166
# tok                tok                162
# and                and                140
# brand              brand               90
# she                she                 90
# wearing            wearing             90
# posted             posted              88
# viral              viral               88
# ://t.co/xiuittpwgv ://t.co/xiuittpwgv  87
# @skyliej_:         @skyliej_:          87

# %% [markdown]
# During this dataframe,
#
#
# word: name of the count words
#
#
# freq: frequencies that each word appears

# %%
write.csv(d,"/Users/yangyilin/Desktop/anly-501-project-YilinYang2000-1/data/00-raw-data/twittertm.csv")

# %% [markdown]
# ## Modified data

# %% [markdown]
# Instagram is one of the most popular and famous platforms for users to network, post their daily lives. There are a lot of famous internet influencers here. Instagram is also one of the important parts for wemedia to develop. Users can create channels to post their daily lives, show their abilities, post some fun videos in order to attract more fans. Ad sellers also analyze their business value to contact instagram influencers to promote their products in order to gain more benefits.
#
# In this dataset, it clearly shows followers'number, average likes each post, country etc. I would like to use this dataset to deeper analyze the trend of internet influencers followers. Country distribution of these influencers. More than this, I would like to use other datasets to locate the fields which these inernet influencers focus to further analyze factors of these internet influencers. What makes them success.

# %% [markdown]
# channel info: Username in instagram
#
# influence score: It is calculated based on their popularity.
#
# posts: total posts they have
#
# followers: total followers they have
#
# avg_likes: average likes of their total posts
#
# 60_days_eng_rate: 60 days of engagement rate
#
# new_post_avg_like: a calculation of the average likes they gained from new posts.
#
# total_likes: total likes of their posts in instagram.
#
# country: users' origin. What countries they from?

# %%
library(tidyverse)
library(dplyr)
library(reshape2)
library(tidyr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.0      ✔ forcats 0.5.2
# ✔ readr   2.1.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths

# %%
instagram_infl = read.csv("/Users/yangyilin/Desktop/anly-501-project-YilinYang2000-1/data/00-raw-data/top_insta_influencers_data.csv")

# %%
head(instagram_infl)
# Out:
#   rank channel_info  influence_score posts followers avg_likes X60_day_eng_rate
# 1 1    cristiano     92              3.3k  475.8m    8.7m      1.39%
# 2 2    kyliejenner   91              6.9k  366.2m    8.3m      1.62%
# 3 3    leomessi      90              0.89k 357.3m    6.8m      1.24%
# 4 4    selenagomez   93              1.8k  342.7m    6.2m      0.97%
# 5 5    therock       91              6.8k  334.1m    1.9m      0.20%
# 6 6    kimkardashian 91              5.6k  329.2m    3.5m      0.88%
#   new_post_avg_like total_likes country
# 1 6.5m              29.0b       Spain
# 2 5.9m              57.4b       United States
# 3 4.4m              6.0b
# 4 3.3m              11.5b       United States
# 5 665.3k            12.5b       United States
# 6 2.9m              19.9b       United States

# %% [markdown]
# At first, I notified there are some NA values in the column country, Because I need to use these columns, so I don't want to drop these values. I decided to change NA values to undefined to explain that these influencers have not defined country.

# %%
instagram_infl$country[instagram_infl$country==""] <- "Undefined"

# %%
head(instagram_infl)
# Out:
#   rank channel_info  influence_score posts followers avg_likes X60_day_eng_rate
# 1 1    cristiano     92              3.3k  475.8m    8.7m      1.39%
# 2 2    kyliejenner   91              6.9k  366.2m    8.3m      1.62%
# 3 3    leomessi      90              0.89k 357.3m    6.8m      1.24%
# 4 4    selenagomez   93              1.8k  342.7m    6.2m      0.97%
# 5 5    therock       91              6.8k  334.1m    1.9m      0.20%
# 6 6    kimkardashian 91              5.6k  329.2m    3.5m      0.88%
#   new_post_avg_like total_likes country
# 1 6.5m              29.0b       Spain
# 2 5.9m              57.4b       United States
# 3 4.4m              6.0b        Undefined
# 4 3.3m              11.5b       United States
# 5 665.3k            12.5b       United States
# 6 2.9m              19.9b       United States

# %% [markdown]
# As we noticed, the avg_likes column contains different unit, I want to expand it as the numeric instead of character in order to do the further visualization and comparison. Here is my code:

# %%
library(stringr)
instagram_infl$avg_likes1 <- str_extract(instagram_infl$avg_likes, "\\d+\\.?\\d*") #extract number without units
instagram_infl$avg_likes1unit <- str_sub(instagram_infl$avg_likes,-1) #extract units since units are last words
instagram_infl$avg_likes1 <- as.numeric(instagram_infl$avg_likes1) #change the new column datatype as num
instagram_infl$avg_likes1 <- ifelse(instagram_infl$avg_likes1unit == 'm', instagram_infl$avg_likes1*1000000, instagram_infl$avg_likes1*1000)
#Since the unit is different, I used the ifelse function to do the further calculation
instagram_infl <- select(instagram_infl,-c(avg_likes,avg_likes1unit))#Drop useless columns
names(instagram_infl)[names(instagram_infl)=='avg_likes1'] <- 'avg_likes'#rename columns
head(instagram_infl)
# Out:
#   rank channel_info  influence_score posts followers X60_day_eng_rate
# 1 1    cristiano     92              3.3k  475.8m    1.39%
# 2 2    kyliejenner   91              6.9k  366.2m    1.62%
# 3 3    leomessi      90              0.89k 357.3m    1.24%
# 4 4    selenagomez   93              1.8k  342.7m    0.97%
# 5 5    therock       91              6.8k  334.1m    0.20%
# 6 6    kimkardashian 91              5.6k  329.2m    0.88%
#   new_post_avg_like total_likes country       avg_likes
# 1 6.5m              29.0b       Spain         8700000
# 2 5.9m              57.4b       United States 8300000
# 3 4.4m              6.0b        Undefined     6800000
# 4 3.3m              11.5b       United States 6200000
# 5 665.3k            12.5b       United States 1900000
# 6 2.9m              19.9b       United States 3500000

# %% [markdown]
# At that time, I used summary and want to know the median, mean, etc values of each numeric number, then I noticed that other columns like posts also cannot convert to numeric since the cells in the column have units. As a result, I decided to get rid of units in each columns and change the column type into numeric

# %%
print(summary(instagram_infl))
# Out:
#       rank        channel_info       influence_score    posts
#  Min.   :  1.00   Length:200         Min.   :22.00   Length:200
#  1st Qu.: 50.75   Class :character   1st Qu.:80.00   Class :character
#  Median :100.50   Mode  :character   Median :84.00   Mode  :character
#  Mean   :100.50                      Mean   :81.82
#  3rd Qu.:150.25                      3rd Qu.:86.00
#  Max.   :200.00                      Max.   :93.00
#   followers         X60_day_eng_rate   new_post_avg_like  total_likes
#  Length:200         Length:200         Length:200         Length:200
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#    country            avg_likes
#  Length:200         Min.   :   65100
#  Class :character   1st Qu.:  504400
#  Mode  :character   Median : 1100000
#                     Mean   : 1787104
#                     3rd Qu.: 2100000
#                     Max.   :15400000

# %%
instagram_infl$posts = substr(instagram_infl$posts,1,nchar(instagram_infl$posts)-1)
instagram_infl$posts = as.numeric(instagram_infl$posts)
names(instagram_infl)[names(instagram_infl)=='posts'] <- 'posts(k)'
instagram_infl$followers = substr(instagram_infl$followers,1,nchar(instagram_infl$followers)-1)
instagram_infl$followers = as.numeric(instagram_infl$followers)
names(instagram_infl)[names(instagram_infl)=='followers'] <- 'followers(m)'
instagram_infl$X60_day_eng_rate = substr(instagram_infl$X60_day_eng_rate,1,nchar(instagram_infl$X60_day_eng_rate)-1)
instagram_infl$X60_day_eng_rate = as.numeric(instagram_infl$X60_day_eng_rate)
names(instagram_infl)[names(instagram_infl)=='X60_day_eng_rate'] <- 'X60_day_eng_rate(%)'
instagram_infl$new_post_avg_like = substr(instagram_infl$new_post_avg_like,1,nchar(instagram_infl$new_post_avg_like)-1)
instagram_infl$new_post_avg_like = as.numeric(instagram_infl$new_post_avg_like)
names(instagram_infl)[names(instagram_infl)=='new_post_avg_like'] <- 'new_post_avg_like(m)'
instagram_infl$total_likes = substr(instagram_infl$total_likes,1,nchar(instagram_infl$total_likes)-1)
instagram_infl$total_likes = as.numeric(instagram_infl$total_likes)
names(instagram_infl)[names(instagram_infl)=='total_likes'] <- 'total_likes(b)'
head(instagram_infl)
# Out:
#   rank channel_info  influence_score posts(k) followers(m) X60_day_eng_rate(%)
# 1 1    cristiano     92              3.30     475.8        1.39
# 2 2    kyliejenner   91              6.90     366.2        1.62
# 3 3    leomessi      90              0.89     357.3        1.24
# 4 4    selenagomez   93              1.80     342.7        0.97
# 5 5    therock       91              6.80     334.1        0.20
# 6 6    kimkardashian 91              5.60     329.2        0.88
#   new_post_avg_like(m) total_likes(b) country       avg_likes
# 1   6.5                29.0           Spain         8700000
# 2   5.9                57.4           United States 8300000
# 3   4.4                 6.0           Undefined     6800000
# 4   3.3                11.5           United States 6200000
# 5 665.3                12.5           United States 1900000
# 6   2.9                19.9           United States 3500000

# %%
summary(instagram_infl)
# Out:
#       rank        channel_info       influence_score    posts(k)
#  Min.   :  1.00   Length:200         Min.   :22.00   Min.   : 0.0100
#  1st Qu.: 50.75   Class :character   1st Qu.:80.00   1st Qu.: 0.9475
#  Median :100.50   Mode  :character   Median :84.00   Median : 2.1000
#  Mean   :100.50                      Mean   :81.82   Mean   : 3.4998
#  3rd Qu.:150.25                      3rd Qu.:86.00   3rd Qu.: 5.0250
#  Max.   :200.00                      Max.   :93.00   Max.   :17.5000
#
#   followers(m)    X60_day_eng_rate(%) new_post_avg_like(m) total_likes(b)
#  Min.   : 32.80   Min.   : 0.010      Min.   :  1.0        Min.   :  1.00
#  1st Qu.: 40.00   1st Qu.: 0.410      1st Qu.:  4.4        1st Qu.:  2.00
#  Median : 50.05   Median : 0.880      Median :149.3        Median :  4.00
#  Mean   : 77.41   Mean   : 1.902      Mean   :247.0        Mean   :142.13
#  3rd Qu.: 68.90   3rd Qu.: 2.035      3rd Qu.:412.3        3rd Qu.: 20.75
#  Max.   :475.80   Max.   :26.410      Max.   :994.4        Max.   :987.40
#                   NA's   :1           NA's   :8
#    country            avg_likes
#  Length:200         Min.   :   65100
#  Class :character   1st Qu.:  504400
#  Mode  :character   Median : 1100000
#                     Mean   : 1787104
#                     3rd Qu.: 2100000
#                     Max.   :15400000

# %%
head(instagram_infl)
# Out:
#   rank channel_info  influence_score posts(k) followers(m) X60_day_eng_rate(%)
# 1 1    cristiano     92              3.30     475.8        1.39
# 2 2    kyliejenner   91              6.90     366.2        1.62
# 3 3    leomessi      90              0.89     357.3        1.24
# 4 4    selenagomez   93              1.80     342.7        0.97
# 5 5    therock       91              6.80     334.1        0.20
# 6 6    kimkardashian 91              5.60     329.2        0.88
#   new_post_avg_like(m) total_likes(b) country       avg_likes
# 1   6.5                29.0           Spain         8700000
# 2   5.9                57.4           United States 8300000
# 3   4.4                 6.0           Undefined     6800000
# 4   3.3                11.5           United States 6200000
# 5 665.3                12.5           United States 1900000
# 6   2.9                19.9           United States 3500000

# %% [markdown]
# Now the dataset is much clean now and it is easy for further calculation. Now we can export dataframe as csv files now.

# %%
write.csv(instagram_infl,"/Users/yangyilin/Desktop/anly-501-project-YilinYang2000-1/data/00-raw-data/instagram_infl.csv")
